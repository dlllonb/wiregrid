# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "../data"

print("Files in ../data:")
for f in os.listdir(data_dir):
    print(f)
# Out:
# Files in ../data:
# beam_map_331F1_pol1.grd
# beam_map_331F1_pol1_brad.grd

# %%
filename = "beam_map_331F1_pol1.grd"
filepath = os.path.join("../data", filename)

with open(filepath, "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip():
        parts = line.split()
        if len(parts) == 3:
            try:
                nx, ny, nz = map(int, parts)
                if nz == 0:
                    grid_line = i
                    break
            except:
                pass

print("Grid line:", grid_line)
print("Grid size:", nx, ny, nz)

data_lines = lines[grid_line + 1:]
rows = []

for line in data_lines:
    parts = line.split()
    if len(parts) == 4:
        rows.append([float(x) for x in parts])

arr = np.array(rows)
print("Data shape:", arr.shape)
# Out:
# Grid line: 11
# Grid size: 256 256 0
# Data shape: (65536, 4)

# %%
img = arr[:, 0].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 1)")
plt.show()

# %%
img = arr[:, 1].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 2)")
plt.show()

# %%
img = arr[:, 2].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 3)")
plt.show()

# %%
img = arr[:, 3].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 4)")
plt.show()

# %%
E1 = arr[:,0] + 1j * arr[:,1]
E2 = arr[:,2] + 1j * arr[:,3]

power = np.abs(E1)**2 + np.abs(E2)**2

img = power.reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar(label="Power")
plt.title("Total Power")
plt.show()

# %%
plt.imshow(np.log10(img + 1e-12), origin="lower", cmap="inferno")
plt.colorbar(label="log10(Power)")
plt.title("Log Power")
plt.show()

# %%
filename = "beam_map_331F1_pol1_brad.grd"
filepath = os.path.join("../data", filename)

with open(filepath, "r") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if line.strip():
        parts = line.split()
        if len(parts) == 3:
            try:
                nx, ny, nz = map(int, parts)
                if nz == 0:
                    grid_line = i
                    break
            except:
                pass

print("Grid line:", grid_line)
print("Grid size:", nx, ny, nz)

data_lines = lines[grid_line + 1:]
rows = []

for line in data_lines:
    parts = line.split()
    if len(parts) == 4:
        rows.append([float(x) for x in parts])

arr = np.array(rows)
print("Data shape:", arr.shape)
# Out:
# Grid line: 10
# Grid size: 256 256 0
# Data shape: (65536, 4)

# %%
img = arr[:, 0].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 1)")
plt.show()

# %%
img = arr[:, 1].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 2)")
plt.show()

# %%
img = arr[:, 2].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 3)")
plt.show()

# %%
img = arr[:, 3].reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar()
plt.title(filename + " (column 4)")
plt.show()

# %%
E1 = arr[:,0] + 1j * arr[:,1]
E2 = arr[:,2] + 1j * arr[:,3]

power = np.abs(E1)**2 + np.abs(E2)**2

img = power.reshape(ny, nx)

plt.imshow(img, origin="lower")
plt.colorbar(label="Power")
plt.title("Total Power")
plt.show()

# %%
plt.imshow(np.log10(img + 1e-12), origin="lower", cmap="inferno")
plt.colorbar(label="log10(Power)")
plt.title("Log Power")
plt.show()
